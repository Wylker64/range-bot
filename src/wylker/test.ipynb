# %%
import requests
from bs4 import BeautifulSoup

# URL of the website
url = 'https://gamerch.com/chunithm/entry/491431'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

def get_songs_info(url):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print("Failed to retrieve the webpage, Status Code:", response.status_code)
        return
    # Split the content into lines and then join from line 446
    lines = response.content.decode().splitlines()
    html_content = '\n'.join(lines[446:])  # Line numbers in Python are 0-based

    # Parse the HTML content
    soup = BeautifulSoup(html_content, 'html.parser')
    print(soup.prettify()[:5000])

    # Look for a table or other elements that might contain the song data
    song_elements = soup.find_all(['table', 'ul', 'ol', 'div'])
    for element in song_elements:
        if element.name == 'table':
            # Handle table
            rows = element.find_all('tr')
            for row in rows:
                cells = row.find_all('td')
                if cells and '15.4' in cells[0].text:
                    song_info = {
                        'title': cells[2].text.strip(),
                        'notes': cells[3].text.strip(),
                        'old_rating': cells[4].text.strip()
                    }
                    print(song_info)
        elif element.name in ['ul', 'ol']:
            # Handle unordered/ordered lists
            items = element.find_all('li')
            for item in items:
                # Add your logic to parse list items
                pass
        elif element.name == 'div':
            # Handle divs
            # Add your logic to parse divs
            pass

    print("Inspection complete.")

# Call the function
get_songs_info(url)
# Out:
# <p>
#  <span style="font-size:18px">
#   <span class="mu__text-bolder">
#    <span style="color:white">
#     Lv15
#    </span>
#   </span>
#  </span>
# </p>
# <div class="mu__table">
#  <table>
#   <thead>
#    <tr class="mu__table--row1">
#     <th class="mu__table--col1">
#      難易度
#     </th>
#     <th class="mu__table--col2">
#      ジャンル
#     </th>
#     <th class="mu__table--col3">
#      タイトル
#     </th>
#     <th class="mu__table--col4">
#      ノート数
#     </th>
#     <th class="mu__table--col5">
#      旧定数
#     </th>
#    </tr>
#   </thead>
#   <tbody>
#    <tr class="mu__table--row2">
#     <th class="mu__table--col1" colspan="5" style="width:33px;text-align:center">
#      15.4
#     </th>
#    </tr>
#    <tr class="mu__table--row3">
#     <td class="mu__table--col1" rowspan="6" style="width:36px;text-align:center;background-color:#c0a0ff">
#      MAS
#     </td>
#    </tr>
#    <tr class="mu__table--row4">
# ...

# %%
import requests
from bs4 import BeautifulSoup

# URL of the website
url = 'https://gamerch.com/chunithm/entry/491431'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

def get_songs_info(url):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print("Failed to retrieve the webpage, Status Code:", response.status_code)
        return

    lines = response.content.decode().splitlines()
    html_content = '\n'.join(lines[445:])  # Start from line 446

    soup = BeautifulSoup(html_content, 'html.parser')

    song_table = soup.find('table')
    if not song_table:
        print("Failed to find the song table in the HTML content starting from line 446.")
        return

    songs = []
    current_level = ''
    for row in song_table.find_all('tr'):
        cells = row.find_all('td')
        if not cells:
            # Check for level header
            header = row.find('th')
            if header and '15.' in header.text:
                current_level = header.text.strip()
            continue

        # Assuming the structure is: title, notes, old rating
        if len(cells) >= 3:
            title = cells[0].text.strip()
            notes = cells[1].text.strip()
            old_rating = cells[2].text.strip()

            song_info = {
                'level': current_level,
                'title': title,
                'notes': notes,
                'old_rating': old_rating
            }
            songs.append(song_info)

    return songs

# Call the function and print the results
songs_info = get_songs_info(url)
for song in songs_info:
    print(song)
# Out:
# {'level': '15.4', 'title': '業 -善なる神とこの世の悪について-', 'notes': '3500', 'old_rating': '-'}
# {'level': '15.4', 'title': 'The Metaverse-First story of the SeelischTact-', 'notes': '3500', 'old_rating': '-'}
# {'level': '15.4', 'title': '祈 -我ら神祖と共に歩む者なり-', 'notes': '4444', 'old_rating': '-'}
# {'level': '15.4', 'title': 'MALKUTH -The Last Ruler of Terrestrials-', 'notes': '3234', 'old_rating': '-'}
# {'level': '15.3', 'title': 'ピアノ協奏曲第１番”蠍火”', 'notes': '1730', 'old_rating': '-'}
# {'level': '15.3', 'title': '混沌を越えし我らが神聖なる調律主を讃えよ', 'notes': '2800', 'old_rating': '-'}
# {'level': '15.3', 'title': 'World Vanquisher', 'notes': '3000', 'old_rating': '-'}
# {'level': '15.3', 'title': "DA'AT -The First Seeker of Souls-", 'notes': '3898', 'old_rating': '-'}
# {'level': '15.3', 'title': 'グラウンドスライダー協奏曲第一番「風唄」', 'notes': '2299', 'old_rating': 'N'}
# {'level': '15.2', 'title': 'macrocosmos', 'notes': '3085', 'old_rating': '-'}
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the website
url = 'https://gamerch.com/chunithm/entry/491431'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

def get_songs_info(url):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print("Failed to retrieve the webpage, Status Code:", response.status_code)
        return

    lines = response.content.decode().splitlines()
    html_content = '\n'.join(lines[507:])  # Start from line 446

    soup = BeautifulSoup(html_content, 'html.parser')

    song_table = soup.find('table')
    if not song_table:
        print("Failed to find the song table in the HTML content starting from line 446.")
        return

    songs = []
    current_level = ''
    for row in song_table.find_all('tr'):
        cells = row.find_all('td')
        if not cells:
            # Check for level header
            header = row.find('th')
            if header and '14.' in header.text:
                current_level = header.text.strip()
            continue

        # Assuming the structure is: title, notes, old rating
        if len(cells) >= 3:
            title = cells[0].text.strip()
            notes = cells[1].text.strip()
            old_rating = cells[2].text.strip()

            song_info = {
                'level': current_level,
                'title': title,
                'notes': notes,
                'old_rating': old_rating
            }
            songs.append(song_info)

    return songs

# Call the function and print the results
songs_info = get_songs_info(url)
for song in songs_info:
    print(song)

df=pd.DataFrame(songs_info)

df.to_csv('songs_info.csv', index=False)
# Out:
# {'level': '14.9', 'title': '患部で止まってすぐ溶ける ～狂気の優曇華院', 'notes': '1832', 'old_rating': '14.8'}
# {'level': '14.9', 'title': 'Elemental Creation', 'notes': '2270', 'old_rating': '-'}
# {'level': '14.9', 'title': 'SON OF SUN', 'notes': '1866', 'old_rating': 'N'}
# {'level': '14.9', 'title': 'Gate of Fate', 'notes': '2455', 'old_rating': '-'}
# {'level': '14.9', 'title': 'Exitium', 'notes': '2323', 'old_rating': 'N'}
# {'level': '14.9', 'title': 'Finite', 'notes': '1377', 'old_rating': '-'}
# {'level': '14.9', 'title': '神威', 'notes': '3390', 'old_rating': '-'}
# {'level': '14.9', 'title': 'A Site De La Rue', 'notes': '2143', 'old_rating': '-'}
# {'level': '14.9', 'title': ']-[|/34<#!', 'notes': '2693', 'old_rating': '-'}
# {'level': '14.9', 'title': 'HAELEQUIN(Original Remaster)', 'notes': '2000', 'old_rating': '-'}
# {'level': '14.9', 'title': '★LittlE HearTs★', 'notes': '1907', 'old_rating': '-'}
# {'level': '14.9', 'title': 'Dengeki Tube', 'notes': '1513', 'old_rating': '-'}
# ...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# URL of the website
url = 'https://gamerch.com/chunithm/entry/491431'
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
}

def get_songs_info(url, start_line, level_header):
    response = requests.get(url, headers=headers)
    if response.status_code != 200:
        print("Failed to retrieve the webpage, Status Code:", response.status_code)
        return

    lines = response.content.decode().splitlines()
    html_content = '\n'.join(lines[start_line:])  # Start from specified line

    soup = BeautifulSoup(html_content, 'html.parser')

    song_table = soup.find('table')
    if not song_table:
        print(f"Failed to find the song table in the HTML content starting from line {start_line}.")
        return

    songs = []
    current_level = ''
    for row in song_table.find_all('tr'):
        cells = row.find_all('td')
        if not cells:
            header = row.find('th')
            if header and level_header in header.text:
                current_level = header.text.strip()
            continue

        if len(cells) >= 3:
            title = cells[0].text.strip()
            notes = cells[1].text.strip()
            old_rating = cells[2].text.strip()

            song_info = {
                'level': current_level,
                'title': title,
                'notes': notes,
                'old_rating': old_rating
            }
            songs.append(song_info)

    return songs


songs_info_15 = get_songs_info(url, 445, '15.')
songs_info_14_plus = get_songs_info(url, 507, '14.')
songs_info_14=get_songs_info(url,744,'14.')
songs_info_13_plus=get_songs_info(url, 1030, '13.')



combined_songs_info = songs_info_15 + songs_info_14_plus + songs_info_14+ songs_info_13_plus
#combined_songs_info= songs_info_14

for song in combined_songs_info:
    print(song)

#print(combined_songs_info)


# 将数据保存为 .json 文件
with open('songs_info.json', 'w', encoding='utf-8') as f:
    json.dump(combined_songs_info, f, ensure_ascii=False, indent=4)

df = pd.DataFrame(combined_songs_info)
df.to_csv('songs_info.csv', index=False)
# Out:
# {'level': '15.4', 'title': '業 -善なる神とこの世の悪について-', 'notes': '3500', 'old_rating': '-'}
# {'level': '15.4', 'title': 'The Metaverse-First story of the SeelischTact-', 'notes': '3500', 'old_rating': '-'}
# {'level': '15.4', 'title': '祈 -我ら神祖と共に歩む者なり-', 'notes': '4444', 'old_rating': '-'}
# {'level': '15.4', 'title': 'MALKUTH -The Last Ruler of Terrestrials-', 'notes': '3234', 'old_rating': '-'}
# {'level': '15.3', 'title': 'ピアノ協奏曲第１番”蠍火”', 'notes': '1730', 'old_rating': '-'}
# {'level': '15.3', 'title': '混沌を越えし我らが神聖なる調律主を讃えよ', 'notes': '2800', 'old_rating': '-'}
# {'level': '15.3', 'title': 'World Vanquisher', 'notes': '3000', 'old_rating': '-'}
# {'level': '15.3', 'title': "DA'AT -The First Seeker of Souls-", 'notes': '3898', 'old_rating': '-'}
# {'level': '15.3', 'title': 'グラウンドスライダー協奏曲第一番「風唄」', 'notes': '2299', 'old_rating': 'N'}
# {'level': '15.2', 'title': 'macrocosmos', 'notes': '3085', 'old_rating': '-'}
# ...
